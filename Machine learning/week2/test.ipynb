# %%
import pandas as pd
import numpy as np

cols = ['population','profits']
df = pd.read_csv("Rest_Pop_Profit.csv",names=cols)

# %%
print(df)
# Out:
#     population   profits
# 0       6.1101  17.59200
# 1       5.5277   9.13020
# 2       8.5186  13.66200
# 3       7.0032  11.85400
# 4       5.8598   6.82330
# ..         ...       ...
# 92      5.8707   7.20290
# 93      5.3054   1.98690
# 94      8.2934   0.14454
# 95     13.3940   9.05510
# 96      5.4369   0.61705
#
# [97 rows x 2 columns]

# %%
print("Target names:", df['population'])
# Out:
# Target names: 0      6.1101
# 1      5.5277
# 2      8.5186
# 3      7.0032
# 4      5.8598
#        ...
# 92     5.8707
# 93     5.3054
# 94     8.2934
# 95    13.3940
# 96     5.4369
# Name: population, Length: 97, dtype: float64

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<AxesSubplot:xlabel='population', ylabel='population'>,
#         <AxesSubplot:xlabel='profits', ylabel='population'>],
#        [<AxesSubplot:xlabel='population', ylabel='profits'>,
#         <AxesSubplot:xlabel='profits', ylabel='profits'>]], dtype=object)

# %%
Y = df['profits']
X = df['population']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.25,random_state=0)
